# %% [markdown]
# # Day 9: Data Analysis and Visualization

# %% [markdown]
# When we plot we need more libraries. You learned about matplot on Day 5, today we are going to build on what you learned and plot directly from pandas and I'm going to introduce seaborn.

# %% [markdown]
# ## Goals for the day:
#
# - Practice making a pivot table
# - More understanding of groupby
# - Introduction to seaborn
# - Introduction to graph automation
#
# ## Functions Learned:
#
# - Create a heatmap: `sns.heatmap()`
# - Create a pairplot: `sns.pairplot()`
# - Create a swarmplot: `sns.swarmplot()`
# - Create a violinplot: `sns.violinplot`

# %% [markdown]
# I will not be able to finish the contents of this notebook but there are many useful tips here so I highly recommend that you complete on your own.

# %%
# this line prints your matplot based plots in this notebook, in some computer without this line your graph will pop out as a window
# %matplotlib inline

#call all the matplot libraries I may need 
import matplotlib.pyplot as plt
from matplotlib import cm

#the usual
import pandas as pd
import numpy as np

#seaborn 
import seaborn as sns; sns.set(color_codes=True)

#some libraries that allow is to run from stats 
import scipy
from scipy import stats

# %% [markdown]
# ## 0. Set Directory

# %%
#this is the specific directory where the data we want to use is stored
datadirectory = '../data/'

#this is the directory where we want to store the data we finish analyzing
data_out_directory='../output/'

# %% [markdown]
# ## Seaborn
# For all the plot examples I am going to do below I am going to use [seaborn](https://seaborn.pydata.org/). You can look at the seaborn [gallery](https://seaborn.pydata.org/examples/index.html) and look at all the plotting options it offers.

# %% [markdown]
# ## 14.Combination skills, Heatplots

# %% [markdown]
# I really want to know what the strongest pokemon type is for each generation and stats (Attack. Def. etc).

# %%
# call in my data 
pokemon=pd.read_csv(datadirectory+'Pokemon.csv')
pokemon.head()
# Out:
#    Number                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0       1              Bulbasaur  Grass  Poison    318  45      49       49
# 1       2                Ivysaur  Grass  Poison    405  60      62       63
# 2       3               Venusaur  Grass  Poison    525  80      82       83
# 3       3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4       4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
### make a pivot table
data_subset=pokemon.pivot_table(values='Attack',index=['Type 1'],columns=['Generation'],aggfunc='min')
data_subset
# Out:
# Generation     1     2     3     4      5     6
# Type 1
# Bug         20.0  10.0  30.0  25.0   40.0  22.0
# Dark         NaN  60.0  55.0  90.0   50.0  54.0
# Dragon      64.0   NaN  70.0  70.0   87.0  50.0
# Electric    30.0  40.0  40.0  45.0   55.0  38.0
# Fairy       45.0  20.0   NaN  50.0    NaN  38.0
# Fighting    80.0  35.0  40.0  70.0   80.0  82.0
# Fire        41.0  40.0  60.0  58.0   30.0  45.0
# Flying       NaN   NaN   NaN   NaN  100.0  30.0
# Ghost       35.0  60.0  40.0  50.0   30.0  66.0
# Grass       40.0  30.0  40.0  30.0   27.0  61.0
# Ground      50.0  60.0  40.0  72.0   66.0   NaN
# Ice         50.0  30.0  40.0  60.0   50.0  69.0
# Normal       5.0  10.0  20.0   5.0   50.0  36.0
# Poison      45.0  90.0  43.0  50.0   50.0  60.0
# Psychic     20.0  33.0  23.0  25.0   25.0  48.0
# Rock        40.0  64.0  41.0  42.0   75.0  50.0
# Steel        NaN  80.0  55.0  24.0   55.0  50.0
# Water       10.0  20.0  15.0  20.0   40.0  53.0

# %% [markdown]
# ## Coding Challenge
# Make a function that makes a pivot table from the pokemon data. This function will allow me to use any aggregation function I want on any pokemon stats I want. The argument for this fuction should be stats_wanted and aggfun_wanted. The index is 'Type 1' and the columns 'Generation'.

# %%
##### your code here
##hint use the code above and change what you need!

def get_summary(stats_wanted,aggfun_wanted):
  data_subset=pokemon.pivot_table(values=stats_wanted,index=['Type 1'],columns=['Generation'],aggfunc=aggfun_wanted)
  return data_subset


get_summary('Speed','max')
# Out:
# Generation      1      2      3      4      5      6
# Type 1
# Bug         145.0   95.0  160.0   95.0  145.0   89.0
# Dark          NaN  115.0  115.0  125.0  106.0   99.0
# Dragon       80.0    NaN  120.0  102.0   97.0   95.0
# Electric    140.0  115.0  135.0   95.0  116.0  109.0
# Fairy        60.0   45.0    NaN   80.0    NaN   99.0
# Fighting     95.0   70.0  100.0  112.0  105.0  118.0
# Fire        105.0  100.0  100.0  108.0  101.0  126.0
# Flying        NaN    NaN    NaN    NaN  121.0  123.0
# Ghost       130.0   85.0   75.0  105.0   80.0   99.0
# Grass        80.0  110.0  145.0  127.0  116.0   68.0
# Ground      120.0   85.0  100.0   95.0  101.0    NaN
# Ice          95.0   75.0  100.0  110.0  105.0   28.0
# Normal      121.0  100.0  125.0  135.0  128.0  102.0
# Poison       90.0  130.0   65.0   95.0   75.0   44.0
# Psychic     150.0  110.0  180.0  115.0  114.0  104.0
# Rock        150.0   71.0   75.0   58.0  110.0  110.0
# Steel         NaN   70.0  110.0   90.0  108.0   75.0
# ...

# %% [markdown]
# ### Answer

# %%
##make a fucntion that will aggregate my data based on whatever aggfun I want

def get_summary(stat_wanted,aggfun_wanted):
  data_subset=pokemon.pivot_table(values=stat_wanted,index=['Type 1'],columns=['Generation'],aggfunc=[aggfun_wanted])
  
  ###drop a level in the columns so the table looks nicer
  data_subset.columns=data_subset.columns.droplevel(0)
  return data_subset

get_summary('Attack','max')
# Out:
# Generation      1      2      3      4      5      6
# Type 1
# Bug         155.0  185.0   90.0   94.0  135.0   52.0
# Dark          NaN   95.0  150.0  125.0  125.0  131.0
# Dragon      134.0    NaN  180.0  170.0  170.0  100.0
# Electric     90.0   95.0   75.0  123.0  115.0   58.0
# Fairy        70.0  120.0    NaN   50.0    NaN  131.0
# Fighting    130.0   95.0  120.0  145.0  140.0  124.0
# Fire        130.0  130.0  160.0  104.0  140.0  110.0
# Flying        NaN    NaN    NaN    NaN  115.0   70.0
# Ghost        65.0   60.0  165.0  120.0   55.0  110.0
# Grass       105.0   82.0  130.0  132.0   98.0  107.0
# Ground      130.0  120.0  180.0  140.0  145.0    NaN
# Ice          85.0  100.0  120.0  130.0  110.0  117.0
# Normal      125.0  130.0  160.0  160.0  128.0   80.0
# Poison      105.0   90.0  100.0  106.0   95.0   75.0
# Psychic     190.0  100.0  180.0  165.0  100.0  160.0
# Rock        135.0  164.0  125.0  165.0  140.0  160.0
# Steel         NaN  125.0  145.0  120.0  100.0  150.0
# ...

# %%
##make a fucntion that will aggregate my data based on whatever aggfun I want

def get_summary(stat_wanted,aggfun_wanted):
  data_subset=pokemon.pivot_table(values=stat_wanted,index=['Type 1'],columns=['Generation'],aggfunc=[aggfun_wanted])
  
  ###drop a level in the columns so the table looks nicer
  #data_subset.columns=data_subset.columns.droplevel(1)

  ## I can select more than one poke stat toplot, but from what I know with pivot you can only do one aggfunction
  return data_subset

get_summary(['Attack','Speed'],('max','min'))
# Out:
#               max                                                             \
#               min
#            Attack
#               max                                      min
# Generation      1      2      3      4      5      6     1     2     3     4
# Type 1
# Bug         155.0  185.0   90.0   94.0  135.0   52.0  20.0  10.0  30.0  25.0
# Dark          NaN   95.0  150.0  125.0  125.0  131.0   NaN  60.0  55.0  90.0
# Dragon      134.0    NaN  180.0  170.0  170.0  100.0  64.0   NaN  70.0  70.0
# Electric     90.0   95.0   75.0  123.0  115.0   58.0  30.0  40.0  40.0  45.0
# Fairy        70.0  120.0    NaN   50.0    NaN  131.0  45.0  20.0   NaN  50.0
# Fighting    130.0   95.0  120.0  145.0  140.0  124.0  80.0  35.0  40.0  70.0
# Fire        130.0  130.0  160.0  104.0  140.0  110.0  41.0  40.0  60.0  58.0
# Flying        NaN    NaN    NaN    NaN  115.0   70.0   NaN   NaN   NaN   NaN
# Ghost        65.0   60.0  165.0  120.0   55.0  110.0  35.0  60.0  40.0  50.0
# ...

# %%
### test if heatmap would look ok
sns.heatmap(get_summary(['Attack'],'max'))
# Out:
# <AxesSubplot:xlabel='None-None-Generation', ylabel='Type 1'>

# %% [markdown]
# ## more pivot

# %%
##make a fucntion that will aggregate my data based on whatever aggfun I want

get_summary(['Attack'],'min')

# %%
##make a fucntion that will aggregate my data based on whatever aggfun I want

get_summary(['Attack','Speed'],('min','max'))

# %% [markdown]
# ## more on groupby--Skip in class--

# %% [markdown]
# We can accomplish the same results with groupby but in my opinion it is less intuitive than pivot table. I wrote the code below to introduce you to group by, it is by no means comprehensive but it will give you a place to start.

# %%
## we can achive something similar with groupby
## in my experience I use pivot tables when I want one agg func and groupby when I want multiple agg funcs
## you can achive the same level of data analysis with pivot and groupby, you just have to find what works for you

def get_summary2(stat_wanted,aggfun_wanted):
  ###step 1, aggregare by type 1 and generation
  #data_subset=pokemon.groupby(['Type 1','Generation']).agg(aggfun_wanted)
  ### step 2 select the column with the stat we want
  #data_subset=pokemon.groupby(['Type 1','Generation'])[stat_wanted].agg(aggfun_wanted)
  ##clean up the index
  data_subset=pokemon.groupby(['Type 1','Generation'])[stat_wanted].agg(aggfun_wanted)
  return data_subset

get_summary2('Attack',['mean'])

# %%
## we can achive something similar with groupby

def get_summary2(stat_wanted,aggfun_wanted):
  ##note that with groupby you can include more columns in stats wanted and more aggfun arguments 
  data_subset=pokemon.groupby(['Type 1','Generation'])[stat_wanted].agg(aggfun_wanted)
  return data_subset

get_summary2(['Attack','Speed'],['max','min'])

# %% [markdown]
# more info on [unstack](https://scentellegher.github.io/programming/2017/07/15/pandas-groupby-multiple-columns-plot.html)

# %%
## we can achive something similar with groupby
## and groupby allows us to have more aggfunctions that pivot table

def get_summary2(stat_wanted,aggfun_wanted):
  ##note that with groupby you can include more columns in stats wanted and more aggfun arguments
  ##however the resulting dataframe has a multi index that makes plotting more dififcult
  ## we can go back to one index by doing unstack 
  data_subset=pokemon.groupby(['Type 1','Generation'])[stat_wanted].agg(aggfun_wanted).unstack()
  return data_subset

get_summary2(['Attack','Speed'],['max','min'])

# %%
sns.heatmap(get_summary2(['Attack','Speed'],['max','min']))

# %% [markdown]
# ## 14.2 Automate graph making

# %% [markdown]
# I really want to create a way to visualize the different stats and figure out what the strongest/weakest pokemon types and pokemon are.

# %% [markdown]
# STEP1. I want to make many heatplots to view diff stats so I want to write my code below in such a way that will allow me to do that.

# %%
for place_in_list,i in enumerate(pokemon.columns):
  print (place_in_list,i)
# Out:
# 0 Number
# 1 Name
# 2 Type 1
# 3 Type 2
# 4 Total
# 5 HP
# 6 Attack
# 7 Defense
# 8 Sp. Atk
# 9 Sp. Def
# 10 Speed
# 11 Generation
# 12 Legendary

# %%
## let's make a list that will hold the variables I want
## when I change the contents of my list the rest of my code will react accordingly 
stats_all=['HP','Attack','Speed','Total']

##call a figure object that always has 1 row but the columns change based on the contents of my list
fig, ax=plt.subplots(nrows=1,ncols=len(stats_all),sharey=True)

#change the figure size by the lenth of my list so my figure is always pretty
fig.set_size_inches(len(stats_all)*4,6)

for count,stat in enumerate(stats_all):
  #print (count,stat)
  ## I'm going to use the output from my function that uses pivot table but you can you anything 
  hold=get_summary(stat,'max')
  sns.heatmap(hold,ax=ax[count],cmap="Reds")
  ax[count].set_ylabel('')
  ax[count].set_title(f'{stat}')

# %%
def get_heat(stats_all,aggfunction_wanted):

  ## let's make a list that will hold the variables I want
  ## when I change the contents of my list the rest of my code will react accordingly 

  ##call a figure object that always has 1 row but the columns change based on the contents of my list
  fig, ax=plt.subplots(nrows=1,ncols=len(stats_all),sharey=True)

  #change the figure size by the lenth of my list so my figure is always pretty
  fig.set_size_inches(len(stats_all*4),6)

  for count,stat in enumerate(stats_all):
    #print (count,stat)
    hold=get_summary(stat,aggfunction_wanted)
    sns.heatmap(hold,ax=ax[count],cmap="Reds")
    ax[count].set_ylabel('')
    ax[count].set_title(f'{stat}')

  plt.show()

# %%
##cool now we can explore the different pokemon stats based on diff math stats
get_heat(stats_all=['HP','Attack','Speed','Total','Sp. Atk'],aggfunction_wanted='max')

# %%
## make a function that quickly lets me view pokemons based on Type 1 and Generation

def get_pokemon(type_1,generation,stat_wanted):
  out=pokemon.loc[((pokemon['Type 1']== type_1)&(pokemon['Generation']==generation))].copy()
  out.sort_values(by=stat_wanted,ascending=False,inplace=True)
  return out

get_pokemon('Psychic',1,'Attack')
# Out:
#      Number                   Name  ... Legendary generation_legend
# 163     150    MewtwoMega Mewtwo X  ...      True            1_True
# 164     150    MewtwoMega Mewtwo Y  ...      True            1_True
# 162     150                 Mewtwo  ...      True            1_True
# 165     151                    Mew  ...     False           1_False
# 105      97                  Hypno  ...     False           1_False
# 70       65               Alakazam  ...     False           1_False
# 71       65  AlakazamMega Alakazam  ...     False           1_False
# 104      96                Drowzee  ...     False           1_False
# 131     122               Mr. Mime  ...     False           1_False
# 69       64                Kadabra  ...     False           1_False
# 68       63                   Abra  ...     False           1_False
#
# [11 rows x 14 columns]

# %% [markdown]
# ## Conclusion:
# Pandas will help you clean, order and analyze your data. Then you can use libraries like seaborn so make figures for your manuscripts.
#
# Google and stackoverflow are your friends, use them!
# Also YOUTUBE is a gold mine. [This](https://www.youtube.com/c/dataschool/videos) is on of my favorite channels but explore and find your own!

# %% [markdown]
# # RUN THE REST OF CODE AND SHOW GRAPHS

# %% [markdown]
# ## 15. Extra: Combination skills, Correlations

# %% [markdown]
# ## Scatter plots

# %% [markdown]
# I want to know what stats values are highly correlated. So I am going to use [sns.regplot ](https://seaborn.pydata.org/generated/seaborn.regplot.html)

# %%
## not specifying how many subplots I want will allow me to add subplots with the for loop
fig = plt.figure()

fig.subplots_adjust(hspace=0.2, wspace=0.2)

## this list can change but it muts always change by the nrow value you specify in the for loop
stats_all=['HP','Attack','Defense','Speed','Sp. Atk','Sp. Def']
fig.set_size_inches(len(stats_all*4),10)

for count,stat in enumerate(stats_all):
    ax = fig.add_subplot(2, 3, count+1)
    ax=sns.regplot(x='Total', y=stat, data=pokemon)

plt.show()
plt.close()

# %% [markdown]
# Cool figure, let's add some labels so we can read it better

# %%
fig = plt.figure()

fig.subplots_adjust(hspace=0.3, wspace=0.2)

stats_all=['HP','Attack','Defense','Speed','Sp. Atk','Sp. Def']
fig.set_size_inches(len(stats_all*4),10)

for count,stat in enumerate(stats_all):
    ax = fig.add_subplot(2, (len(stats_all)/2), count+1)
    ax=sns.regplot(x='Total', y=stat, data=pokemon)

    ##get stats for a label
    temp=pokemon[['Total',stat]].dropna()
    results=stats.linregress(temp.iloc[:,0],temp.iloc[:,1])
    #print (results)

    ##this code makes the labels in the box
    props=dict(boxstyle='round',facecolor='white',alpha=.9)
    textstr='m={:.3f}\nb={:.3f}\n$r^2$={:.3f}\np={:.3}'.format(results[0],results[1],results[2]**2,results[3]) #grabs the values from stats_out
    ax.text(.75,.05,textstr,transform=ax.transAxes,va='bottom',fontsize=11,bbox=props) #change the formatting of the box

    #this code here allows me to make a line manually
    x1=np.array([temp.Total.min(),temp.Total.max()])
    y1=results[0]*x1+results[1]
    ax.plot(x1,y1)

    ## add line equation as a title
    m=results[0]
    b=results[1]
    ax.set_title('y={:.3f}x+{:.3f}'.format(m,b))


plt.show()
plt.close()

# %% [markdown]
# Let's make the code into a function so we can easily change what we plot

# %%
def correlates_with_wanted(stats_wanted):

  fig = plt.figure()
  fig.subplots_adjust(hspace=0.3, wspace=0.2)

  stats_all=['HP','Attack','Defense','Speed','Sp. Atk','Sp. Def','Total']
  stats_all.remove(stats_wanted)

  fig.set_size_inches(len(stats_all*4),10)

  for count,stat in enumerate(stats_all):
      # remeber that add_subplots is (nrow,ncol,number) and number starts at 1 while enumerate at 0
      ax = fig.add_subplot(2, (len(stats_all)/2), count+1)
      ax=sns.regplot(x=stats_wanted, y=stat, data=pokemon)

      ##get stats for a label
      temp=pokemon[[stats_wanted,stat]].dropna()
      results=stats.linregress(temp.iloc[:,0],temp.iloc[:,1])
      #print (results)

      props=dict(boxstyle='round',facecolor='white',alpha=.9)
      textstr='m={:.3f}\nb={:.3f}\n$r^2$={:.3f}\np={:.3}'.format(results[0],results[1],results[2]**2,results[3]) #grabs the values from stats_out
      ax.text(.75,.05,textstr,transform=ax.transAxes,va='bottom',fontsize=11,bbox=props) #change the formatting of the box

      #this code here woul allow to make a line manually
      x1=np.array([temp[stats_wanted].min(),temp[stats_wanted].max()])
      y1=results[0]*x1+results[1]
      ax.plot(x1,y1)

      ## add line equation as a title
      m=results[0]
      b=results[1]
      ax.set_title('y={:.3f}x+{:.3f}'.format(m,b))


  plt.show()
  plt.close()

correlates_with_wanted('Defense')

# %% [markdown]
# ## Table of correlations

# %%
### make a table of correlations

stats_all=['HP','Attack','Defense','Speed','Sp. Atk','Sp. Def','Total']

stats_df=pd.DataFrame(index=stats_all,columns=stats_all)

for i in stats_all:
  for k in stats_all:
    stats_results=stats.linregress(pokemon[i],pokemon[k])
    #print(stats_results)
    stats_df[i][k]=stats_results[2].round(2)

stats_df
# Out:
#            HP Attack Defense Speed Sp. Atk Sp. Def Total
# HP          1   0.42    0.24  0.18    0.36    0.38  0.62
# Attack   0.42      1    0.44  0.38     0.4    0.26  0.74
# Defense  0.24   0.44       1  0.02    0.22    0.51  0.61
# Speed    0.18   0.38    0.02     1    0.47    0.26  0.58
# Sp. Atk  0.36    0.4    0.22  0.47       1    0.51  0.75
# Sp. Def  0.38   0.26    0.51  0.26    0.51       1  0.72
# Total    0.62   0.74    0.61  0.58    0.75    0.72     1

# %%
### a faster trick
corr_all=pokemon.corr()
corr_all
# Out:
#               Number     Total        HP  ...     Speed  Generation  Legendary
# Number      1.000000  0.119813  0.097614  ...  0.010733    0.982516   0.153396
# Total       0.119813  1.000000  0.618748  ...  0.575943    0.048384   0.501758
# HP          0.097614  0.618748  1.000000  ...  0.175952    0.058683   0.273620
# Attack      0.102298  0.736211  0.422386  ...  0.381240    0.051451   0.345408
# Defense     0.094786  0.612787  0.239622  ...  0.015227    0.042419   0.246377
# Sp. Atk     0.088759  0.747250  0.362380  ...  0.473018    0.036437   0.448907
# Sp. Def     0.085817  0.717609  0.378718  ...  0.259133    0.028486   0.363937
# Speed       0.010733  0.575943  0.175952  ...  1.000000   -0.023121   0.326715
# Generation  0.982516  0.048384  0.058683  ... -0.023121    1.000000   0.079794
# Legendary   0.153396  0.501758  0.273620  ...  0.326715    0.079794   1.000000
#
# [10 rows x 10 columns]

# %% [markdown]
# ## Density plots

# %% [markdown]
# Once you have code that works all you need to do is change the plot kind and it will work

# %%
sns.set(style="dark")

def density_with_wanted(stats_wanted):

  fig = plt.figure()
  fig.subplots_adjust(hspace=0.3, wspace=0.2)

  stats_all=['HP','Attack','Defense','Speed','Sp. Atk','Sp. Def','Total']
  stats_all.remove(stats_wanted)

  fig.set_size_inches(len(stats_all*3),10)

  for count,stat in enumerate(stats_all):
      # remeber that add_subplots is (nrow,ncol,number) and number starts at 1 while enumerate at 0
      ax = fig.add_subplot(2, (len(stats_all)/2), count+1)
      x,y=pokemon[stats_wanted],pokemon[stat]
      ##change the kind of figure you want
      sns.kdeplot(x, y, cmap='Reds', shade=True, ax=ax)

  plt.show()
  plt.close()

density_with_wanted('Speed')

# %% [markdown]
# we can make the function a little more complicated by adding in another for loop. This will make it so that each subplots has multiple plots inside.

# %%
sns.set(style="dark")

def density_with_wanted(stats_wanted):

  fig = plt.figure()
  fig.subplots_adjust(hspace=0.3, wspace=0.2)

  stats_all=['HP','Attack','Defense','Speed','Sp. Atk']
  stats_all.remove(stats_wanted)

  fig.set_size_inches(len(stats_all*3),10)

  for count,stat in enumerate(stats_all):
    # remeber that add_subplots is (nrow,ncol,number) and number starts at 1 while enumerate at 0
    ax = fig.add_subplot(2, (len(stats_all)/2), count+1)
    for gen in [1,2,4,5]:
      pokemon_subset=pokemon.loc[pokemon['Generation']==gen]
      x,y=pokemon_subset[stats_wanted],pokemon_subset[stat]
      sns.kdeplot(x, y, shade=True, ax=ax,shade_lowest=False, n_levels=3)

  plt.show()
  plt.close()

density_with_wanted('Speed')

# %% [markdown]
# ## 16. Extra: Data exploration

# %% [markdown]
# Once you have cleaned up your datatable it is really easy to plot. You just look for the kind of plot you want and specify the data you want. You can play around with the variables until you get something meaningful.

# %% [markdown]
# ## Pairplots

# %% [markdown]
# Like the plots we manually made above, [Pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html) allows you to see relationships between variables.

# %%
sns.pairplot(pokemon[['Type 1','Attack','Defense','Speed','Total','Legendary']],hue='Legendary')

# %%
sns.pairplot(pokemon[['Type 1','Attack','Defense','Speed','Total','Generation']],hue='Generation')

# %%
pokemon['generation_legend']=pokemon['Generation'].astype(str)+'_'+pokemon['Legendary'].astype(str)
pokemon.head()
# Out:
#    Number                   Name  ... Legendary generation_legend
# 0       1              Bulbasaur  ...     False           1_False
# 1       2                Ivysaur  ...     False           1_False
# 2       3               Venusaur  ...     False           1_False
# 3       3  VenusaurMega Venusaur  ...     False           1_False
# 4       4             Charmander  ...     False           1_False
#
# [5 rows x 14 columns]

# %% [markdown]
# let's make our new figure, and change some details using [palette](https://matplotlib.org/3.2.1/tutorials/colors/colormaps.html)

# %%
sns.pairplot(pokemon[['Type 1','Attack','Defense','Speed','Total','generation_legend']],hue='generation_legend',palette='tab20',corner=True,)

# %% [markdown]
# ## Swarmplots
# I wanted to explore the Legendary distrubution more so I looked in seaborn to see what kinds of plots are used for categorical data and swarmplots came up.

# %%
##this calls the style of the plot 
sns.set(style="whitegrid", palette="muted")

#this calls the actual swarmplot
sns.swarmplot(x="Legendary", y="Attack", hue="Generation", data=pokemon)

# %%
sns.swarmplot(x="Generation", y="Attack", hue="Legendary", data=pokemon)

# %%
fig, ax=plt.subplots()
fig.set_size_inches(5,10)

sns.swarmplot(x="Legendary", y="Speed", hue="Generation", data=pokemon,ax=ax)
ax.set_title('Legendary')

plt.savefig(data_out_directory+'swarm.pdf')

# %% [markdown]
# ## Coding challenge
#
# Here is the website on how to make [violinplots](https://seaborn.pydata.org/generated/seaborn.violinplot.html) with seaborn.

# %%
#### using the full pokemon data
### make a violinplot where the x is Attack, y is Type 1, and hue is legendary
## remeber to change the figure size so the figure is readable

# %% [markdown]
# ### Answer

# %%
#@title
fig, ax=plt.subplots()

fig.set_size_inches(5,15)

sns.violinplot(x="Attack", y="Type 1", data=pokemon, hue='Legendary',ax=ax)

ax.set_title('My violin plots')
# Out:
# Text(0.5, 1.0, 'My violin plots')

# %% [markdown]
# # 17.Extra fun

# %% [markdown]
# THIS IS HOW YOU MAKE PLOTS
#
# 1. call figure and create your canvas
# ... fig, ax= plt.subplots()
#
# 2. follow instructions on websites for the actual plot you want
# ...some plot code
#
# 3. change some stuff
# ....ax.set_title('My plot title')
#
# 4. save the plot if you want...
# plt.savefig('My_plot')

# %% [markdown]
# ## cluster with heatmap

# %% [markdown]
# more code [here](https://seaborn.pydata.org/generated/seaborn.clustermap.html)

# %%
### let's select the legendary and work with those
pokemon_legend=pokemon.loc[pokemon['Legendary']==True,]
pokemon_legend
# Out:
#      Number                 Name  ... Legendary generation_legend
# 156     144             Articuno  ...      True            1_True
# 157     145               Zapdos  ...      True            1_True
# 158     146              Moltres  ...      True            1_True
# 162     150               Mewtwo  ...      True            1_True
# 163     150  MewtwoMega Mewtwo X  ...      True            1_True
# ..      ...                  ...  ...       ...               ...
# 795     719              Diancie  ...      True            6_True
# 796     719  DiancieMega Diancie  ...      True            6_True
# 797     720  HoopaHoopa Confined  ...      True            6_True
# 798     720   HoopaHoopa Unbound  ...      True            6_True
# 799     721            Volcanion  ...      True            6_True
#
# [65 rows x 14 columns]

# %%
sns.clustermap(pokemon_legend[['Attack','Defense','Speed','Sp. Atk','Sp. Def']])

# %% [markdown]
# ## Venn Diagrams

# %% [markdown]
# I just googled python venn diagrams and searched through some of the pages that came out.
# more info [HERE](https://towardsdatascience.com/how-to-create-and-customize-venn-diagrams-in-python-263555527305)

# %%
pip install matplotlib_venn

# %%
from matplotlib_venn import venn3
 
# Make the diagram, code from the website I listed
## I'm just going to add some stuff the website did not show

#call figure and create your canvas
fig, ax= plt.subplots()

## follow instructions on website
venn3(subsets = (20, 10, 12, 10, 9, 4, 3), set_labels = ('Group A', 'Group B', 'Group C'), alpha = 0.5,ax=ax)

##change some stuff
ax.set_title('My Venn')

#save the plot if you want.
#plt.savefig('My_Venn')
# Out:
# Text(0.5, 1.0, 'My Venn')
